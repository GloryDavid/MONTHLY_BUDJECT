# %% [markdown]
# # Personal Expenses Tracker

# %% [markdown]
# ## What are we tracking????

# %% [markdown]
# ### Create Variables

# %%
user = "Glory" # str
current_month = 'December 2025' # str
currency = '$' # str
budget = 800.00 # float
num_days_in_month = 31 # int
is_budget_set = True # Boolean

# %%
print('Hello', user)
# Out:
# Hello Glory

# %%
print('Budget for', current_month, ':', budget)
# Out:
# Budget for December 2025 : 800.0

# %% [markdown]
# ### A single expense

# %%
item = 'Rent'
amount = 400.00
category = 'Housing'
is_necessary = True

# %%
closing_balance = budget - amount
closing_balance
# Out:
# 400.0

# %%
item = 'Rent'

# %%
items = ['Rent', 'Electricity', 'Clothes', 'data bundle', 'KFC', 'Netflix']
prices = [400.00, 50.00, 70.00, 30, 80, 10]
categories = ['Housing', 'Utility', 'Basic', 'Utility', 'Food', 'Entertainment']
necessary = [True, True, True, True, False, False]

# %%
prices
# Out:
# [400.0, 50.0, 70.0, 30, 80, 10]

# %%
prices[0] + prices[1] + prices[2] + prices[3] + prices[4] + prices[5]
# Out:
# 640.0

# %%
total_expences = sum(prices)

# %%
balance = budget - total_expences
balance
# Out:
# 160.0

# %%
num_of_items = len(items)
num_of_items
# Out:
# 6

# %%
print("=" * 35)
print("        Expenses Tracker")
print("=" * 35)
print("Owner",'               ',user)
print("=" * 35)
print("Period", '              ',current_month)
print('-' * 35)
print("Currency", '            ',currency)
print("=" * 35)
print("Starting Balance", '    ',budget)
print("=" * 35)
print("Total Expences", '      ',total_expences)
print('-' * 35)
print("Closing Balance", '     ', balance)
print("=" * 35)
print("Transactions", '        ',num_of_items)
print("=" * 35)
print("       See you next month")
print("=" * 35)
# Out:
# ===================================
#         Expenses Tracker
# ===================================
# Owner                 Glory
# ===================================
# Period                December 2025
# -----------------------------------
# Currency              $
# ===================================
# Starting Balance      800.0
# ===================================
# Total Expences        640.0
# -----------------------------------
# Closing Balance       160.0
# ===================================
# Transactions          6
# ===================================
#        See you next month
# ===================================
